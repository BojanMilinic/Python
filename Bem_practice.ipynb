# %%
import os
from pathlib import Path

# %%
import pandas as pd #for creating dataframe
import pyodbc #working with ODBC databases
import numpy as np # for locating values in dataframes
from datetime import datetime # for obtaining today's date
import os #for working with directories

# %%
default_directory = os.getcwd()
print(default_directory)
# Out:
# c:\Users\bmilinic\OneDrive - DOI\Documents\Python

# %%
cwd = Path.cwd()
home = Path.home()
print(cwd,"\n",home)
# Out:
# c:\Users\bmilinic\OneDrive - DOI
#  C:\Users\bmilinic

# %%
path = Path()
fullpath = path.resolve()
fullpath
# Out:
# WindowsPath('C:/Users/bmilinic/OneDrive - DOI')

# %%
print(fullpath.parents[2])
# Out:
# C:\

# %%
os.chdir('P:')
print(os.getcwd())
# Out:
# P:\

# %%
os.chdir('P:/0083/analysis/DataCompilation/DataCompilationPy/create_site_info_files')

# %%
dfbmj3 = pd.read_csv(r'data_inputs/gwsi_old/bmj3_fromPy.csv')

# %%
Gfe_db = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ=P:\0083\analysis\DataCompilation\DataCompilationPy\local_access_db\BemidjiMasterSiteData_fe.accdb;')
c_fe = Gfe_db.cursor()

# %%
tblSites = pd.read_sql('select * from tblSites', Gfe_db)
tblWells = pd.read_sql('select * from tblWells', Gfe_db)
# Out:
# c:\Users\bmilinic\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
# c:\Users\bmilinic\Anaconda3\lib\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
tblSites
# Out:
#      AgencyCode  Wellcon_SiteRecordID DatabasePointType      USGS_siteno  \
# 0          USGS                   NaN              None             None
# 1          USGS                   NaN              None             None
# 2          USGS                   NaN              None             None
# 3          USGS                   NaN              None             None
# 4          USGS                   NaN              None             None
# ...         ...                   ...               ...              ...
# 1724       USGS                   NaN              Data             None
# 1725       USGS                   NaN              Data  473424095053001
# 1726       USGS                   NaN              Data             None
# 1727       USGS                   NaN              Data             None
# 1728       USGS                   NaN              Data             None
#
#      ProjectAccountNumber                        USGS_StationName  \
# 0                MN-09500                                    None
# 1                MN-09500                                    None
# 2                MN-09500                                    None
# 3                MN-09500                                    None
# 4                MN-09500                                    None
# ...                   ...                                     ...
# 1724             MN-09500                                    None
# 1725             MN-09500  1711G-01  Bemidji Toxics Research Site
# 1726             MN-09500                                    None
# 1727             MN-09500                                    None
# 1728             MN-09500                                    None
#
#      LocalSiteName StateDistrictCode CountryCode  StateCode  ...  \
# 0            15-N6                MN          US       27.0  ...
# 1            15-N7                MN          US       27.0  ...
# 2            15-N8                MN          US       27.0  ...
# 3            15-N9                MN          US       27.0  ...
# 4           15-N10                MN          US       27.0  ...
# ...            ...               ...         ...        ...  ...
# 1724          1713                MN          US       27.0  ...
# 1725      1711G-01                MN          US       27.0  ...
# 1726        WT1712                MN          US       27.0  ...
# 1727          1704                MN          US       27.0  ...
# 1728          1706                MN          US       27.0  ...
#
#                         SiteEstablishedForWhom OilSmell SiteVerticalSource  \
# 0                                         None     None             D-15.1
# 1                                         None     None             D-15.1
# 2                                         None     None             D-15.1
# 3                                         None     None             D-15.1
# 4                                         None     None             D-15.1
# ...                                        ...      ...                ...
# 1724            Silvia Rossbach & Carol Beaver        Y               D-17
# 1725  Geoff Delin, Jared Trost, Barbara Bekins        Y               D-17
# 1726   Ean Warren, Barbara Bekins, Jared Trost        Y               D-17
# 1727             David Podgorski & Phoebe Zito        N               D-17
# 1728             David Podgorski & Phoebe Zito        Y               D-17
#
#       SiteActiveStatus  XLocal_m_FromArc  YLocal_m_FromArc  OnNWT  \
# 0               Active               NaN               NaN    NaN
# 1               Active               NaN               NaN    NaN
# 2               Active               NaN               NaN    NaN
# 3               Active               NaN               NaN    NaN
# 4               Active               NaN               NaN    NaN
# ...                ...               ...               ...    ...
# 1724            Active               NaN               NaN    NaN
# 1725            Active               NaN               NaN    NaN
# 1726            Active               NaN               NaN    NaN
# 1727            Active               NaN               NaN    NaN
# 1728            Active               NaN               NaN    NaN
#
#      Comments_Status ApproxRemovalDate  StudySite
# 0               None              None    Bemidji
# 1               None              None    Bemidji
# 2               None              None    Bemidji
# 3               None              None    Bemidji
# 4               None              None    Bemidji
# ...              ...               ...        ...
# 1724            None              None    Bemidji
# 1725            None              None    Bemidji
# 1726            None              None    Bemidji
# 1727            None              None    Bemidji
# 1728            None              None    Bemidji
#
# [1729 rows x 63 columns]

# %%
os.chdir(r'c:\Users\bmilinic\OneDrive - DOI\Documents\Python')

# %%
# Out:
# c:\Users\bmilinic\OneDrive - DOI\Documents\Python
